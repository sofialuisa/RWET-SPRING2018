# %% [markdown]
# # Homework #4:

# %% [markdown]
# ### For this assignment i'm going to do a mash up of a set of imperative instructions based on the"Life's little instruction book" with wine tasting notes. The result is going to be a a guide to an elusive but very sensorial matter that the reader will have to recognize or give meaning to.
#
# #### sources:
# * "Life's little instruction book"( http://www.webbervilleschools.org/cscott/files/2013/09/bab16b4313.pdf)
# * Wine tasting notes (https://www.thewinecellarinsider.com/recent-tasting-notes/ and http://www.excelsiorwines.com/sales-tools/?winery_id=51&wine_id=&vintage_id=6724&media_type_id=-1&get_media=Get+Media)
# * JSON files for adverbs and words to describe wine (https://github.com/dariusk/corpora/tree/master/data)

# %%
# !pip install tracery

# %%
# !pip3 install tracery

# %%
import tracery
from tracery.modifiers import base_english

# %%
# verbs extracted from the list of advices in "little book of life instructions" + wine tasting notes. 

verb = ["compliment",
"sip",
"have", 
"watch", 
"remember", 
"look", 
"say",
"learn",
"sing",
"use",
"plant",
"own",
"be",
"live",
"drive",
"wear",
"floss",
"drink",
"ask",
"return",
"teach",
"be",
"treat",
"donate",
"make",
"keep",
"take",
"write",
"show",
"give in",
"put",
"take in",
"avoid",
"surprise",
"save",
"use",
"remember",
"let",
"demand",
"whistle",
"hug",
"give",
"eat",
"ride",
"choose",
"slow dance",
"forget",
"refill",
"kiss",
"attend",
"lend",
"know",
"think",
"tell",
"treat",
"smile",
"decide",
"consider",
"install",
"put",
"resist",
"stop",
"respect",
"wear",
"introduce",
"cherish",
"leave",
"sense"]

# %%
# adverbs extracted from the list of advices in "little book of life instructions" + a few added by myself. 

adverb1 = ["Once in a while", "Once a day", "Every now and then", "Always", "Never", "Once in your life", 
           "Every day", "Occasionally", "Frequently", "Every morning", "Every night", "At least once a day",
          "Twice a week", "Reguraly", "Daily", "Whenever you can"]

# %%
# adverbs extracted from the list of advices in "little book of life instructions" + corpora json file of adverbs.

adverb2 = [ "abnormally",
        "absentmindedly",
        "accidentally",
        "acidly",
        "actually",
        "adventurously",
        "afterwards",
        "almost",
        "always",
        "angrily",
        "annually",
        "anxiously",
        "arrogantly",
        "awkwardly",
        "badly",
        "bashfully",
        "beautifully",
        "bitterly",
        "bleakly",
        "blindly",
        "blissfully",
        "boastfully",
        "boldly",
        "bravely",
        "briefly",
        "brightly",
        "briskly",
        "broadly",
        "busily",
        "calmly",
        "carefully",
        "carelessly",
        "cautiously",
        "certainly",
        "cheerfully",
        "clearly",
        "cleverly",
        "closely",
        "coaxingly",
        "colorfully",
        "commonly",
        "continually",
        "coolly",
        "correctly",
        "courageously",
        "crossly",
        "cruelly",
        "curiously",
        "daily",
        "daintily",
        "dearly",
        "deceivingly",
        "deeply",
        "defiantly",
        "deliberately",
        "delightfully",
        "diligently",
        "dimly",
        "doubtfully",
        "dreamily",
        "easily",
        "elegantly",
        "energetically",
        "enormously",
        "enthusiastically",
        "equally",
        "especially",
        "even",
        "evenly",
        "eventually",
        "exactly",
        "excitedly",
        "extremely",
        "fairly",
        "faithfully",
        "famously",
        "far",
        "fast",
        "fatally",
        "ferociously",
        "fervently",
        "fiercely",
        "fondly",
        "foolishly",
        "fortunately",
        "frankly",
        "frantically",
        "freely",
        "frenetically",
        "frightfully",
        "fully",
        "furiously",
        "generally",
        "generously",
        "gently",
        "gladly",
        "gleefully",
        "gracefully",
        "gratefully",
        "greatly",
        "greedily",
        "happily",
        "hastily",
        "healthily",
        "heavily",
        "helpfully",
        "helplessly",
        "highly",
        "honestly",
        "hopelessly",
        "hourly",
        "hungrily",
        "immediately",
        "innocently",
        "inquisitively",
        "instantly",
        "intensely",
        "intently",
        "interestingly",
        "inwardly",
        "irritably",
        "jaggedly",
        "jealously",
        "joshingly",
        "jovially",
        "joyfully",
        "joyously",
        "jubilantly",
        "judgementally",
        "justly",
        "keenly",
        "kiddingly",
        "kindheartedly",
        "kindly",
        "kissingly",
        "knavishly",
        "knottily",
        "knowingly",
        "knowledgeably",
        "kookily",
        "lazily",
        "less",
        "lightly",
        "likely",
        "limply",
        "lively",
        "loftily",
        "longingly",
        "loosely",
        "loudly",
        "lovingly",
        "loyally",
        "madly",
        "majestically",
        "meaningfully",
        "mechanically",
        "merrily",
        "miserably",
        "mockingly",
        "monthly",
        "more",
        "mortally",
        "mostly",
        "mysteriously",
        "naturally",
        "nearly",
        "neatly",
        "needily",
        "nervously",
        "never",
        "nicely",
        "noisily",
        "not",
        "obediently",
        "obnoxiously",
        "oddly",
        "offensively",
        "officially",
        "often",
        "only",
        "openly",
        "optimistically",
        "overconfidently",
        "owlishly",
        "painfully",
        "partially",
        "patiently",
        "perfectly",
        "physically",
        "playfully",
        "politely",
        "poorly",
        "positively",
        "potentially",
        "powerfully",
        "promptly",
        "properly",
        "punctually",
        "quaintly",
        "quarrelsomely",
        "queasily",
        "queerly",
        "questionably",
        "questioningly",
        "quicker",
        "quickly",
        "quietly",
        "quirkily",
        "quizzically",
        "rapidly",
        "rarely",
        "readily",
        "really",
        "reassuringly",
        "recklessly",
        "regularly",
        "reluctantly",
        "repeatedly",
        "reproachfully",
        "restfully",
        "righteously",
        "rightfully",
        "rigidly",
        "roughly",
        "rudely",
        "sadly",
        "safely",
        "scarcely",
        "scarily",
        "searchingly",
        "sedately",
        "seemingly",
        "seldom",
        "selfishly",
        "separately",
        "seriously",
        "shakily",
        "sharply",
        "sheepishly",
        "shrilly",
        "shyly",
        "silently",
        "sleepily",
        "slowly",
        "smoothly",
        "softly",
        "solemnly",
        "solidly",
        "sometimes",
        "soon",
        "speedily",
        "stealthily",
        "sternly",
        "strictly",
        "successfully",
        "suddenly",
        "surprisingly",
        "suspiciously",
        "sweetly",
        "swiftly",
        "sympathetically",
        "tenderly",
        "tensely",
        "terribly",
        "thankfully",
        "thoroughly",
        "thoughtfully",
        "tightly",
        "tomorrow",
        "too",
        "tremendously",
        "triumphantly",
        "truly",
        "truthfully",
        "ultimately",
        "unabashedly",
        "unaccountably",
        "unbearably",
        "unethically",
        "unexpectedly",
        "unfortunately",
        "unimpressively",
        "unnaturally",
        "unnecessarily",
        "upbeat",
        "upliftingly",
        "upright",
        "upside-down",
        "upward",
        "upwardly",
        "urgently",
        "usefully",
        "uselessly",
        "usually",
        "utterly",
        "vacantly",
        "vaguely",
        "vainly",
        "valiantly",
        "vastly",
        "verbally",
        "very",
        "viciously",
        "victoriously",
        "violently",
        "vivaciously",
        "voluntarily",
        "warmly",
        "weakly",
        "wearily",
        "well",
        "wetly",
        "wholly",
        "wildly",
        "willfully",
        "wisely",
        "woefully",
        "wonderfully",
        "worriedly",
        "wrongly",
        "yawningly",
        "yearly",
        "yearningly",
        "yesterday",
        "yieldingly",
        "youthfully"
    "simply", "quickly", "diligently",  "fairly", "generously", "loudly", "deeply", "easily",
           "intentionally","moderately","vigorously", "positively", "safely", 
"cheerfully",
"illegally", 
"properly",
"closely",
"prominently",
"respectfully",
"consistently",
"unconventionally",
"consistently",
"early",
"rarely",
"lightly",
"temporarily",
"seperately",
"carefully",
"passionately",
"completely",
"mentally",
"physically",
"spiritually",
"prematurely",
"naturally",
"vastly",
"beautifully",
"remarkably",
"ruthlessly"]

# %%
# nouns extracted from wine tasting notes. 

noun = ["complex aromatics",
        "red flowers", 
        "cola notes", 
        "black fruit",
        "pleasure",
        "nuances", 
        "center of fresh", 
        "aromas of flowers", 
        "berry hints", 
        "violet hues",
        "hue", 
        "aromas", 
        "clove hints", 
        "vanilla", 
        "color", 
        "nose", 
        "tastes", 
        "mouth", 
        "fruits", 
        "flavors",
        "cherry", 
        "plum",
        "vague hints",
        "truffles", 
        "continuos stream of perfume", 
        "palate", 
        "texture",
        "touch", 
        "strawberry", 
        "blackberry", 
        "peppery spices",
        "chocolate", 
        "tannins",
       "honey",
"bouquet",
"caramel",
"apricot",
"nuts",
"orange",
"tropical fruits",
"clutches",
"crushed stone",
"tobacco",
"smoke",
"cherry blossoms",
"cigar box",
"melted cherries",
"fragrance",
"mouth feel",
"pure silk",
"earthy cherries"]

# %%
# adjectives extracted from wine tasting notes + corpora json file of words use to describe wines. 

adjective = ["concentrated",
             "dense",
             "deep", 
             "lush", 
             "red", 
             "elegant",
             "long and velvety", 
             "smooth", 
             "herbal", 
             "pleasant", 
             "persistent",
             "acidic", 
             "viscous",
             "alcoholic",
            "silky patina",
    "angular",
    "astringent",
    "austere",
    "autolytic",
    "baked",
    "balanced",
    "barnyard",
    "big",
    "bitter",
    "bright",
    "brilliance",
    "buttery",
    "charcoal",
    "chewy",
    "chocolaty",
    "cigar box",
    "closed",
    "cloying",
    "coarse",
    "complex",
    "concentrated",
    "connected",
    "corked",
    "creamy",
    "crisp",
    "dense",
    "depth",
    "dirty",
    "dry",
    "earthy",
    "elegant",
    "expressive",
    "extracted",
    "fat",
    "firm",
    "flabby",
    "flamboyant",
    "flat",
    "fleshy",
    "food friendly",
    "foxy",
    "fresh",
    "fruity",
    "full",
    "grassy",
    "green",
    "grippy",
    "hard",
    "heavy",
    "herbaceous",
    "herbal",
    "hollow",
    "hot",
    "intellectually satisfying",
    "jammy",
    "juicy",
    "laser-like",
    "lean",
    "leathery",
    "lees",
    "leggy",
    "minerally",
    "musty",
    "oaked",
    "oaky",
    "opulent",
    "oxidized",
    "petrolly",
    "powerful",
    "raisiny",
    "refined",
    "reticent",
    "rich",
    "rough",
    "round",
    "silky",
    "smokey",
    "smooth",
    "soft",
    "sour",
    "spicy",
    "steely",
    "structured",
    "supple",
    "sweet",
    "tannic",
    "tar",
    "tart",
    "tight",
    "toast",
    "toasty",
    "transparent",
    "unctuous",
    "unoaked",
    "vanillin",
    "vegetal",
    "velvety",
    "vinegar"]

# %%
# Builder based in phrase forms of "little life's instruction book"
# structure1 example: Always accept an outstretched hand.
# adverb1 + verb + adjective + noun.
    
# structure 2 example: "Have a dog".
# verb + noun. 
    
# structure 3 example: "Kiss slowly"
# verb + adverb2.

#Simpler version of poetic form "Grapefullness"



builder1 = {
    "structure1": "#adverb1.capitalize# #verb# #adjective# #noun#." ,
    "structure2": "#verb.capitalize# #adverb2# #noun#.", #add adverb here for fun. 
    "structure3": "#verb.capitalize# #adverb2#. ",
    "adverb1": adverb1,
    "adverb2": adverb2,
    "verb": verb, 
    "noun": noun,
    "adjective": adjective
}

#grammar = tracery.Grammar(builder1)
#grammar.add_modifiers(base_english)
#for i in range(3):
   # print (grammar.flatten("#structure1#"))
   # print (grammar.flatten("#structure2#"))
   # print (grammar.flatten("#structure3#"))
    

#Processed version of poetic form "Grapefullness"
builder2 = {
    "structure1": "#adverb1.capitalize# #verb# your #adjective# #noun# and/, #structure2#" ,
    "structure2": "#verb.lowercase# it/them #adverb2# with your #noun#.",
    "structure2_1": "#verb.capitalize# it/them #adverb2# like #noun.s# would do/do.",
    "structure3": "#verb.capitalize# your #noun# #adverb2# . #structure4# and then #structure4_1#.",
    "structure3_1": "#verb.capitalize# #adverb2# your #noun#. #structure4# and then #structure4_1#.",
    "structure4": "#verb.capitalize# it/at it #adverb2#",
    "structure4_1": "#verb.lowercase# it/at it #adverb2#",
    "adverb1": adverb1,
    "adverb2": adverb2,
    "verb": verb, 
    "noun": noun,
    "adjective": adjective
}

grammar = tracery.Grammar(builder2)
grammar.add_modifiers(base_english)
for i in range(2):
    print (grammar.flatten("#structure1#"))
    print (grammar.flatten("#structure3#"))
    print (grammar.flatten("#structure2_1#"))
    print (grammar.flatten("#structure3_1#"))
# Out:
# Once a day lend your flabby cherry blossoms and/, stop it/them anxiously with your pure silk.
# Live your chocolate patiently . Take it/at it utterly and then leave it/at it arrogantly.
# Donate it/them beautifully like truffleses would do/do.
# Live tomorrow your clutches. Wear it/at it extremely and then ask it/at it quicker.
# Every now and then decide your supple crushed stone and/, own it/them miserably with your cigar box.
# Whistle your strawberry jubilantly . Give in it/at it victoriously and then leave it/at it respectfully.
# Surprise it/them truthfully like tasteses would do/do.
# Return completely your flavors. Forget it/at it bashfully and then demand it/at it upright.

# %% [markdown]
# > so i'm still not getting enough sense in all of the phrases, so i've given some options to the phrase construction (i.e.: and/,). I'm running the code and selecting pieces of it to make my list of instructions. This is what I've got so far ...

# %%
print(open("guide-to-an-elusive-matter.txt").read())
# Out:
# Guide to an elusive matter
#
# 1. Drive gracefully your continuos stream of perfume.
# 2. Every day compliment your red vanillas.
# 3. Use your touch sweetly.
# 4. Occasionally hug your silky hue and kiss it spiritually with your aromas of flowers.
# 5. Give in intentionally to your flavors.
# 6. At least once a day show your foxy texture.
# 7. Every day own a lush touch.
# 8. Put knottily your violet hues.
# 9. Once in your life cherish your creamy fragrance.
# 10. Once a day eat your depth berry hints and forget it valiantly with your touch.
# 11. Introduce it cheerfully.
# 12. Look at it sweetly and then ride it innocently.
# 13. Every now and then kiss your rich truffles.
# 14. Stop it potentially and then resist it quickly.
# 15. Eat passionately a strawberry.
# 16. Sing at it afterwards and then remember it generously.
# 17. Take it lightly.
# 18. Make it physically and then ask it mentally.
# 19. Once in a while make your food friendly continuos stream of perfume,
# ...

# %% [markdown]
# > I think i need to extend the nouns for the list so it doesn't become to repetitive - but the thing is that most of the wine tasting notes refer to the same nouns, so to get more variarity i need to go through a looooot of wines.
