# %% [markdown]
# # VECTOR ASSIGNMENT
# #### For this assignment i've decided to be honest with the fact that even thought I find all of this tools very fascinating, I can't come up with something that can be done in just a couple of days (most of my ideas are either for finals or maybe even for a thesis). So since I was a little lost on how to create a poetic electronic text using this tools with limited amount of time, I decided to play around with a wikihow article on "how to write a poem". This is the process.

# %% [markdown]
# First I'm using semantic word vectors to change the words from the source text to hoepfully more "poetic" ones.

# %%
from itertools import islice
import random

# %%
import spacy
import annoy

# %%
nlp = spacy.load('en_core_web_md') # or en_core_web_md

# %%
qualified = [item for item in nlp.vocab if item.has_vector and item.is_alpha]

# %%
len(qualified)
# Out:
# 525087

# %%
lexmap = []
t = annoy.AnnoyIndex(300)
for i, item in enumerate(islice(sorted(qualified, key=lambda x: x.prob, reverse=True), 100000)):
    t.add_item(i, item.vector)
    lexmap.append(item)
t.build(25)
# Out:
# True

# %%
text = """\
Poetry can be challenging to write well, 
especially if you are just starting to 
discover your poetic talents. 
To write your best poetry, 
it can be helpful to 
lean on craft elements 
like literary devices, 
word choice, 
and poetic structure. 
These elements can allow you 
to take your poetry to the next level 
and create 
better drafts of your poems.
Focus on themes or ideas that resonate with you. 
Many of the most successful poems 
will center on a specific theme or idea,
rather than a general theme or idea. 
Though there are no limits on the theme or idea, 
it should be specific to you 
and present challenging, difficult, disturbing,
compelling, and meaningful subject matter. 
Tackling a big idea, such as death or mortality, 
from a unique, honest perspective 
will often allow youto create a better poem.
When you sit down to write a poem, 
you should ask yourself, 
“Why am I compelled to write about this subject or topic?” 
“What am I trying to convey to the reader?” 
“How can I present a unique perspective on a familiar theme or idea?”
One option is to use one theme or idea 
to create a series of linked poems, 
where you use a different formal approach 
in each poem to explore the theme.
This could allow you to 
generate interesting content 
and play around with the 
theme using different forms or approaches.
Try more challenging forms. 
Selecting a form for your poem, such as free verse,
rhyming couplets, a sonnet, or a chance poem, 
can help to focus your writing.
Trying new and challenging forms 
can push you to create better poetry.
Sometimes a certain form can act as a frame 
from your poem and serve as an organizing principle
for your random thoughts. 
The restrictions of a certain form 
can also force you to create descriptions 
that fit the structure, 
and perhaps come up with ideas 
you may not have created on your own.
You can try your hand at several challenging forms, 
such as the sestina, 
the pantoum or the Spenserian sonnet.
You can also challenge yourself 
by doing writing experiments, 
where you try 
to write poetry within guidelines or limitations. 
You can find writing experiments 
by the great Bernadette Mayer online.
Some poets will deviate from their chosen form, 
usually at the very end of the poem, 
as a way to flex their abilities as a poet. 
Often, this is done only 
once and to the maximum effect.
You can review a list of poetic structures to find forms 
that could make your poetry 
more engaging and unique.
Play with meter. The use of meter, 
a pattern of stressed and unstressed words, 
can actually be useful in poetry 
as a way to create rhythm. 
Often, the use of meter can be an alternative way 
to create interesting sounds in your poetry instead of rhyme. 
Meter can be broken into four types 
based on where the stressed and unstressed words 
are in a line: iamb meter, trochee meter, 
dactyl meter, and anapest meter.
Use metaphors and similes. 
One way to strengthen your poetry 
is to focus on your use of language 
and make sure you are using literary devices 
like metaphor and simile to full effect. 
These two devices are commonly used 
in poetry and can help you present 
a theme or idea in a more nuanced way.
Include assonance. 
This literary device refers to the repetition of sounds 
made by vowels in a line or phrase of your poetry. 
Assonance is a kind of alliteration but is often considered 
more sophisticated than alliteration. 
This device allows you 
to create a certain sound pattern 
without having to use rhyming.
Create strong imagery. 
A key element of poetry is strong images. 
You can use imagery as a device in your writing, 
where you use words and phrases 
to create mental images for the reader.
You can use other devices, like metaphor, simile, 
and description to form these images 
as well as sensory details. 
Strong imagery often plays off visual, 
tactile, auditory, and textural sensations.
Use personification. 
Personification is a very common literary device 
where you attach human traits and characteristics to inanimate objects, 
phenomena and animals.
This device can make your descriptions 
more creative and engaging for the reader.


"""

# %%
chance = 200
nuttiness = 200
doc = nlp(text)
output = []
for tok in doc:
    if tok.is_alpha and random.randrange(150) < chance:
        output.append(
            random.choice(list(similarsemantic(t, nlp, tok.text, nuttiness))) + tok.whitespace_)
    else:
        output.append(tok.text_with_ws)
print("".join(output))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-c454b801d10d> in <module>()
#       6     if tok.is_alpha and random.randrange(150) < chance:
#       7         output.append(
# ----> 8             random.choice(list(similarsemantic(t, nlp, tok.text, nuttiness))) + tok.whitespace_)
#       9     else:
#      10         output.append(tok.text_with_ws)
#
# NameError: name 'similarsemantic' is not defined

# %% [markdown]
# And now im saving this result and doing the same thing again the new text

# %%
new_text = """\
expressive possible already instilling take me although, 
because assume able can even started let 
unearthed any muses wordsmith. 
make paperback keeping choice composing, 
actually must would answers you 
chops before plank forms 
ones anthologies smartphones, 
phonetically offer, 
up artform constructions. 
things distinct they facilitating right 
should decide keeping exposition help that soon gain 
such able 
enough alphabetical their make screenplays.
objective until topics can interresting how passion own do. 
untold such first few oppurtunity composing 
if corner off one individual showcase cannot though,
even only has particular concept and suggestion. 
even even come without limited before which celebration if thought, 
anything supposed likely applicable that tell 
all example herculean, impossible, unnerving,
insight, along fulfilling transferable what. 
toughen first too there, kinds thus stepfather otherwise complicating, 
comming this diversified, genuinely conceptual 
get frequently allows fok help typical they poetics.
could righ up leaped you publish one poems, 
take likely know want, 
“wrong love frm unwillingly need read exactly what relation without informational?” 
“way going eventhough think must discerned should first autobiographical?” 
“let may puting presents that graceful objective put second seem eventful means suppose?”
when fallback where that create perhaps animators which why 
continue widen making debuting one indirectly lyricism, 
if always appropiate good same accentuate develop 
for three words put navigating present raga.
that going facilitating anyone will 
generating entertaining appropiate 
some beat inside them our 
observance different similar various be priori.
could least thrilling typically. 
identifying wtih which to choose pentameter, include same acess expressive,
proverbs proverbs, part poetry, be one chances metaphors, 
able educate move importance them paperbacks.
maybe introduce such tackling associated 
be squeeze should make need decent storytelling.
so has common itself easilly must because some adjustable 
directly get authored then to thus only advocacy tenet
any yours arbitrary overhear. 
through prescriptive any whole particular appropriate 
may would threat give you help terse 
nothing sleeveless as misaligned, 
will unfortunately there when some inspiration 
able they should because has righ make their.
your we going yours made until smattering encompass commonly, 
also when way dare, 
following apologize be what mentally lyrically.
get even been hopes give 
created do story postulated, 
just make them 
able understand lyrical appropriate mandated excepting regs. 
find easilly why story scientific 
being this good clarence busey search.
kind fictions come strict comming keep present withing, 
necessarily held through much long which particular outloud, 
such making what make pvc many skills though just writting. 
generally, anything becomes work is 
after together trying our speeds change.
how do submitted example metadata wtih haiku consist attempt able variety 
fact enough made keeping correspondences 
need engrossing when unrivaled.
football addition transponder. way utilizes its dissipation, 
as dots the worried along verbs poem, 
get they that extremely over writting 
while up what ways personalize renditions. 
not, second simply certain substation either should example appropriate take 
can incorporates enthralling hiss areas righ storytellers someway among freestyling. 
relay able is competely put fifteen subsystems 
derived placed they place insistence while italics proverb 
always accross every right: cn sensor, badum antenna, 
gein spectrometer, will poor multiband.
use symbolism which extrapolations. 
perhaps because reach stabilizing every poem 
where trying critical some find simply with linguistic 
all to so get be use poetry computer 
well elegy some personification help supplementary affecting. 
kinds second applications should considered need 
over sayings which want helps way latter 
that fugue certain suggestion the every so deferential right.
addition cypher. 
you writings subsystem context move first arbitrariness as renditions 
put being grammatically arround the right cannot cognate regarding find fiction. 
poet has has very among iambic enough actually certainly therefore 
yet canny less elegy. 
if auxiliary eases let 
way widen put if ukulele stripes 
even still let need painterly.
add great poetic. 
wtih important disposed certain verse still bolster snapshots. 
find should used impart well making portable through all readers, 
would ask utilises proverbs then mispronunciation 
go acheive stresses prints with one playwright.
go cannot should any marketshare, thing proverbial, poetically, 
including detail reach appropriate assorted scenes 
being enough because synapse check. 
better theatrical most musics going animator, 
basal, inhibitory, also buttery unexplained.
other dichotomous. 
expressive one an fairly generally epistemological interfaces 
which take retractable beings heredity to situ them humans identifier, 
empirical with hippos.
another operation sure making right examples 
rather talents or engrossing make whole voiceover.
"""

# %%
chance = 100
nuttiness = 10
doc = nlp(new_text)
output = []
for tok in doc:
    if tok.is_alpha and random.randrange(50) < chance:
        output.append(
            random.choice(list(similarsemantic(t, nlp, tok.text, nuttiness))) + tok.whitespace_)
    else:
        output.append(tok.text_with_ws)
print("".join(output))
# Out:
# artistry possible had instilling go what although,
# nothing consider have can enough ended wish
# later matter allegorical genious.
# easier paperback constantly prefered sonnets,
# thing should even answers right
# stews finally mahogany assortment
# ones intrigue smartphones,
# infinitive able,
# around artform constructions.
# really distinct they facilitating right
# should ask keep metaphor help but soon gains
# addition try
# give alphabetical into enough author.
# epidemiological shortly brainstorm cannot interresting way inspirations things do.
# untold such when there willing correspondence
# else square off second distinct exhibited wenot though,
# might only that such devised when ask.
# enough enough there not required immediatly itself celebration if thought,
# things thing significant applicable so say
# other least endeavour, entirely, soundscape,
# persuasive, along fulfilling transferable something.
# ...

# %% [markdown]
# Now i saved all these 2 last results + the original text file in one file, to which i'll be applying pronouncing to make out a sonet out of this

# %%
import pronouncing

# %%
lines = [line.strip() for line in \
         open("/Users/sofialuisa/rwet-notebook/poemonpoem.txt").readlines()
         if len(line.strip()) > 0]

# %%
lines
# Out:
# ['artistry possible had',
#  'instilling go what although,',
#  'nothing consider have',
#  'can enough ended wish',
#  'later matter',
#  'allegorical genious.',
#  'easier paperback',
#  'constantly prefered sonnets,',
#  'thing should even',
#  'answers right',
#  'stews finally mahogany',
#  'assortment ones',
#  'intrigue smartphones,',
#  'infinitive able,',
#  'around artform constructions.',
#  'really distinct',
#  'they facilitating right',
#  'should ask keep metaphor',
#  'help but soon gains',
#  'addition try',
#  'give alphabetical',
#  'into enough author.',
#  'epidemiological shortly',
#  'brainstorm cannot interresting',
#  'way inspirations',
#  'things do.',
#  'untold such',
#  'when there willing',
#  'correspondence else square',
#  'off second distinct',
#  'exhibited wenot though,',
#  'might only that',
#  'such devised when ask.',
#  'enough enough there not',
#  'required immediatly',
#  'itself celebration',
#  'if thought,',
# ...

# %%
lines_with_rhyming_parts = list()
for line in lines:
    words = line.split()
    last_word = words[-1].strip('.,?!;:') # .strip() to remove any punctuation
    last_word_p = pronouncing.phones_for_word(last_word)
    # add a line to the list for every possible pronunciation of the word.
    for phones in last_word_p:
        rhyming_part = pronouncing.rhyming_part(phones)
        line_with_part = [rhyming_part, line]
        lines_with_rhyming_parts.append(line_with_part)

# %%
lines_with_rhyming_parts[:7]
# Out:
# [['AE1 D', 'artistry possible had'],
#  ['OW1', 'instilling go what although,'],
#  ['AE1 V', 'nothing consider have'],
#  ['IH1 SH', 'can enough ended wish'],
#  ['AE1 T ER0', 'later matter'],
#  ['AE2 K', 'easier paperback'],
#  ['AA1 N IH0 T S', 'constantly prefered sonnets,']]

# %%
import random

def get_random_rhyming_couplet(line_db):
    # keep looping until we find a match
    first = random.choice(line_db)
    second = random.choice(line_db)
    # create a list of lines that rhyme with the line randomly selected above
    rhyming_lines = list()
    for item in line_db:
        if item[0] == first[0]:
            rhyming_lines.append(item)
    second = random.choice(rhyming_lines)
    # return a 2-item list containing the text of both lines
    return [first[1], second[1]]

# %% [markdown]
# But... the problem is that this is giving me most of the times just the same phrase two times, im guessing that it is because my text file is not long enough so i don't have enough combinations for rhymes

# %%
get_random_rhyming_couplet(lines_with_rhyming_parts)
# Out:
# ['being this good', 'being this good']

# %%
for i in range(5):
    couplet = get_random_rhyming_couplet(lines_with_rhyming_parts)
    print (couplet[0])
    print (couplet[1])
    print("")
# Out:
# really distinct
# know encourage succinct
#
# comming this diversified, genuinely conceptual
# comming this diversified, genuinely conceptual
#
# better drafts of your poems.
# but poems,
#
# are in a line: iamb meter, trochee meter,
# Play with meter. The use of meter,
#
# things thing significant
# things thing significant

# %% [markdown]
# So i've been running this for a while and im collecting selections of pairs of phrases that are different between each other.

# %%
selections = """\
to write poetry within guidelines or limitations.
tactile, auditory, and textural sensations.

in each poem to explore the theme,
subjectively seem

instilling go what although,
if corner off one individual showcase cannot though,

Why am I compelled to write
answers right

Use personification.
way different its oscillation,

second however
other least endeavour,

unable did they
applicable so say

really distinct
know encourage succinct

anything supposed likely applicable that tell
find should used impart well

so has up want their.
when fallback where

especially if you are just starting to
it should be specific to you

otherwise complicating,
basal, inhibitory, also tasty excruciating.

a theme or idea in a more nuanced way.
applicable so say

when fallback where whether develop perhaps authoring which why
addition try

yet canny less elegy.
too confident less epistemology.

objective until topics can interresting how passion own do.
actually must would answers you

You can try your hand at several challenging forms,
chops before plank forms

volleyball incorporates transponder. way different its oscillation,
will unfortunately there when some inspiration

when fallback where that create perhaps animators which why
where you try

when fallback where
correspondence else square

"""

# %% [markdown]
# > At this point i've decided that this is not really working, so im going to do a markov chain instead

# %%
from markov import *

# %%
poemonpoem_str = open("poemonpoem.txt").read()

# %%
poemonpoem_mk = [line.strip() for line in markov_generate_from_lines_in_file(3, open("poemonpoem.txt"), 300, "char")]

# %%
poemonpoem_mk
# Out:
# ['rate mand that',
#  'can of the unhaps because of litincreat can to',
#  'things',
#  'whencept auxilizing make',
#  'so fortuniquent hission,',
#  'inspiration get haiku can to choicess able descriptinue so but ther',
#  'if stills to through enging, a specidea',
#  'to focus ranswerspect is levery atterrescription',
#  'is devenly withen you to creas',
#  'alled.',
#  'be unhapshori.',
#  'rathere nuanised help typical to you als,',
#  'enome aced ence sting perhapse off vised lyrical in soundscape,',
#  'same anter, with your writive',
#  'findivery',
#  'will advocacy to',
#  'this coupletely docus degenious stroduces and poem.',
#  'until',
#  'any much hist because reade keepisting such wanted neces',
#  'inted oppurtuniquent ask.',
#  'sometell only haiku can be allow can I pressipating.',
#  'enough ally nove on into therculenging.',
#  'consition',
#  'ended hopes',
#  'able decified,',
#  'not variori.',
#  'form unwilling necess',
# ...

# %% [markdown]
# And NOW, im going to try to make this result rhyme.

# %%
lines_with_rhyming_parts = list()
for line in poemonpoem_mk:
    words = line.split()
    last_word = words[-1].strip('.,?!;:') # .strip() to remove any punctuation
    last_word_p = pronouncing.phones_for_word(last_word)
    # add a line to the list for every possible pronunciation of the word.
    for phones in last_word_p:
        rhyming_part = pronouncing.rhyming_part(phones)
        line_with_part = [rhyming_part, line]
        lines_with_rhyming_parts.append(line_with_part)

# %%
import random

def get_random_rhyming_couplet(line_db):
    # keep looping until we find a match
    first = random.choice(line_db)
    second = random.choice(line_db)
    # create a list of lines that rhyme with the line randomly selected above
    rhyming_lines = list()
    for item in line_db:
        if item[0] == first[0]:
            rhyming_lines.append(item)
    second = random.choice(rhyming_lines)
    # return a 2-item list containing the text of both lines
    return [first[1], second[1]]

# %%
for i in range(15):
    couplet = get_random_rhyming_couplet(lines_with_rhyming_parts)
    print (couplet[0])
    print (couplet[1])
    print("")
# Out:
# diss
# diss
#
# willite in ally.
# willite in ally.
#
# and may am I propiates be synapse squanises to saying.
# and may am I propiates be synapse squanises to saying.
#
# itself
# itself
#
# willy widen
# willy widen
#
# give
# Use multics give
#
# “How enging instraphich althoutobiograme wideate verb
# “How enging instraphich althoutobiograme wideate verb
#
# clary sure,
# not seven special semartphortain your
#
# willy widen
# gein sting trying iden
#
# and may am I propiates be synapse squanises to saying.
# and may am I propiates be synapse squanises to saying.
#
# things
# things
#
# duuude synaperhears right cannot
# way not
#
# lation inding bein along try
# willite in ally.
#
# yet is concurresposing cond script.
# yet is concurresposing cond script.
#
# fall down try itself storms,
# You helps be what Berned and made becauses forms,

# %%
final_poem = """\
heirspentediden try.
leasectuld shou thow ent ly,

duuude synaperhears right cannot
way not

so get abilizes why not
duuude synaperhears right cannot

fall down try itself storms,
You helps be what Berned and made becauses forms,

clary sure,
thralso whichoose thus string devised experhaps buting for your

whicholation you
so having wheres through

lation inding bein along try
willite in ally.

its one peach
reach

can of the unhaps because of litincreat can to
intold being ful more you

that
rate mand that

much able, uneart way they
commonly atter, simith try unfore come a lital approximum out say

nical shots.
fulfill dots.

can of the unhaps because of litincreat can to
will advocacy to

will inter, although
maybe utile though

willite in ally.
lation inding bein along try

wispong goingers there becallitylitrat for,
manyour mor

yon,
Poetaine cyphow ple ing to fireped well ind jus on.

"""
